# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, count, variance, udf
import matplotlib.pyplot as plt
from pyspark.sql.window import Window

# %%
spark_session = SparkSession.builder\
.master("spark://192.168.2.129:7077")\
.appName("Analysis_emil")\
.config("spark.dynamicAllocation.enabled", False)\
.config("spark.dynamicAllocation.shuffleTracking.enabled",False)\
.config("spark.shuffle.service.enabled", False)\
.config("spark.dynamicAllocation.executorIdleTimeout","30s")\
.config("spark.cores.max", 4)\
.getOrCreate()

spark_context = spark_session.sparkContext
spark_context.setLogLevel("ERROR")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/03/15 00:37:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark_session.read.csv("hdfs://192.168.2.129:50000/hdfs/data/MSD_Sub_as_CSV.csv", header=True)
df.show()
# Out:
# +----------+------------------+-------+--------------------+-------------------+------------------+--------------+--------------------+---------------+--------------------+------------+---------+------+-------------------+------------+----------------------+----+-------+-------------+-----------------------+--------------------+----+
# |SongNumber|            SongID|AlbumID|           AlbumName|  ArtistFamiliarity|          ArtistID|ArtistLatitude|      ArtistLocation|ArtistLongitude|          ArtistName|Danceability| Duration|Energy|            Hotness|KeySignature|KeySignatureConfidence|Mode|  Tempo|TimeSignature|TimeSignatureConfidence|               Title|Year|
# +----------+------------------+-------+--------------------+-------------------+------------------+--------------+--------------------+---------------+--------------------+------------+---------+------+-------------------+------------+----------------------+----+-------+-------------+-----------------------+--------------------+----+
# |         1|SOMZWCG12A8C13C480| 300848|         Fear Itself| 0.5817937658450281|ARD7TVE1187B99BFB1|          null|     California - LA|           null|              Casual|         0.0|218.93179|   0.0| 0.6021199899057548|           1|                 0.736|   0| 92.198|            4|                  0.778|    I Didn't Mean To|   0|
# |         2|SOCIWDW12A8C13D406| 300822|          Dimensions| 0.6306300375898077|ARMJAGH1187FB546F3|      35.14968|          Memphis TN|      -90.04892|        The Box Tops|         0.0|148.03546|   0.0|                nan|           6|                 0.169|   0|121.274|            4|                  0.384|           Soul Deep|1969|
# |         3|SOXVLOJ12AB0189215| 514953|Las Numero 1 De L...| 0.4873567909281477|ARKRRTF1187B9984DA|          null|                null|           null|    Sonora Santanera|         0.0|177.47546|   0.0|                nan|           8|                 0.643|   1| 100.07|            1|                    0.0|     Amor De Cabaret|   0|
# |         4|SONHOTT12A8C13493C| 287650|       Friend Or Foe| 0.6303823341467806|AR7G5I41187FB4CE6C|          null|      London England|           null|            Adam Ant|         0.0|233.40363|   0.0|                nan|           0|                 0.751|   1|119.293|            4|                    0.0|     Something Girls|1982|
# |         5|SOFSOCN12A8C143F5D| 611336|       Muertos Vivos| 0.6510456608317947|ARXR32B1187FB57099|          null|                null|           null|                 Gob|         0.0|209.60608|   0.0| 0.6045007385888197|           2|                 0.092|   1|129.738|            4|                  0.562|      Face the Ashes|2007|
# |         6|SOYMRWW12A6D4FAB14|  41838|        Ordinary Day| 0.5352927355118197|ARKFYS91187B98E58F|          null|                null|           null|Jeff And Sheri Ea...|         0.0| 267.7024|   0.0|                nan|           5|                 0.635|   1|147.782|            3|                  0.454|The Moon And I (O...|   0|
# |         7|SOMJBYD12A6D4F8557|  25824|   Da Ghetto Psychic| 0.5564956019129572|ARD0S291187B9B7BF5|          null|                Ohio|           null|             Rated R|         0.0|114.78159|   0.0|                nan|           1|                   0.0|   1|111.787|            1|                    0.0|Keepin It Real (S...|   0|
# |        20|SOZVMJI12AB01808AF| 541101|Whatever Happened...|0.32031437017067216|ARNPAGP1241B9C7FD4|          null|                null|           null|           lextrical|         0.0|165.69424|   0.0|                0.0|           7|                 0.011|   1|138.331|            4|                  0.127|     Synthetic Dream|   0|
# +----------+------------------+-------+--------------------+-------------------+------------------+--------------+--------------------+---------------+--------------------+------------+---------+------+-------------------+------------+----------------------+----+-------+-------------+-----------------------+--------------------+----+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- SongNumber: string (nullable = true)
#  |-- SongID: string (nullable = true)
#  |-- AlbumID: string (nullable = true)
#  |-- AlbumName: string (nullable = true)
#  |-- ArtistFamiliarity: string (nullable = true)
#  |-- ArtistID: string (nullable = true)
#  |-- ArtistLatitude: string (nullable = true)
#  |-- ArtistLocation: string (nullable = true)
#  |-- ArtistLongitude: string (nullable = true)
#  |-- ArtistName: string (nullable = true)
#  |-- Danceability: string (nullable = true)
#  |-- Duration: string (nullable = true)
#  |-- Energy: string (nullable = true)
#  |-- Hotness: string (nullable = true)
#  |-- KeySignature: string (nullable = true)
#  |-- KeySignatureConfidence: string (nullable = true)
#  |-- Mode: string (nullable = true)
#  |-- Tempo: string (nullable = true)
#  |-- TimeSignature: string (nullable = true)
#  |-- TimeSignatureConfidence: string (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- Year: string (nullable = true)

# %%
data1 = df.select("Duration","KeySignature","Tempo","Year").filter(df["Year"]!=0)
data1 = data1.select(*(col(c).cast("float").alias(c) for c in data1.columns))
data2 = Window.partitionBy("Year")
data3 = data1.withColumn("Mean Duration", avg("Duration").over(data2))
data3 = data3.withColumn("Mean Key", avg("KeySignature").over(data2))
data3 = data3.withColumn("Mean Tempo", avg("Tempo").over(data2))
data3 = data3.withColumn("Var Duration", variance("Duration").over(data2))
data3 = data3.withColumn("Var Key", variance("KeySignature").over(data2))
data3 = data3.withColumn("Var Tempo", variance("Tempo").over(data2))
data3 = data3.withColumn("Count", count("Year").over(data2))
data3.show()
# Out:
# [Stage 4:>                                                          (0 + 1) / 1]
# +---------+------------+-------+------+------------------+-----------------+------------------+-------------------+------------------+------------------+-----+
# | Duration|KeySignature|  Tempo|  Year|     Mean Duration|         Mean Key|        Mean Tempo|       Var Duration|           Var Key|         Var Tempo|Count|
# +---------+------------+-------+------+------------------+-----------------+------------------+-------------------+------------------+------------------+-----+
# |175.15057|         4.0|101.676|1926.0| 176.7701644897461|              2.5|101.00250244140625|  5.246148455073126|               4.5|0.9072046644287184|    2|
# |178.38976|         1.0|100.329|1926.0| 176.7701644897461|              2.5|101.00250244140625|  5.246148455073126|               4.5|0.9072046644287184|    2|
# |188.94322|         4.0| 99.076|1927.0|188.69941202799478|5.666666666666667| 131.0653305053711| 10.035365612323707|14.333333333333336|1005.7583616354386|    3|
# |191.73833|         3.0|131.624|1927.0|188.69941202799478|5.666666666666667| 131.0653305053711| 10.035365612323707|14.333333333333336|1005.7583616354386|    3|
# |185.41669|        10.0|162.496|1927.0|188.69941202799478|5.666666666666667| 131.0653305053711| 10.035365612323707|14.333333333333336|1005.7583616354386|    3|
# |191.11137|         6.0|114.177|1929.0| 191.1113739013672|              6.0|  114.177001953125|               null|              null|              null|    1|
# |196.62321|        10.0|107.877|1930.0| 196.7538299560547|              5.0| 133.3219985961914|0.03412067890167236|              50.0|1294.8960189392092|    2|
# |196.88445|         0.0|158.767|1930.0| 196.7538299560547|              5.0| 133.3219985961914|0.03412067890167236|              50.0|1294.8960189392092|    2|
# |  173.322|         5.0|100.795|1934.0|173.32200622558594|              5.0|100.79499816894531|               null|              null|              null|    1|
# |163.91791|        11.0| 96.982|1935.0|176.09097290039062|             11.0|  87.7400016784668| 296.36703202314675|               0.0| 170.8291494353034|    2|
# |188.26404|        11.0| 78.498|1935.0|176.09097290039062|             11.0|  87.7400016784668| 296.36703202314675|               0.0| 170.8291494353034|    2|
# |192.80934|         4.0| 38.443|1936.0|192.80934143066406|              4.0| 38.44300079345703|               null|              null|              null|    1|
# |172.30322|         6.0|107.081|1940.0|165.65505981445312|              6.0|101.54150009155273|   88.3961383420974|               0.0| 61.37214687213418|    2|
# | 159.0069|         6.0| 96.002|1940.0|165.65505981445312|              6.0|101.54150009155273|   88.3961383420974|               0.0| 61.37214687213418|    2|
# |181.08035|         9.0|142.398|1947.0|177.90647888183594|              9.0|113.62449645996094| 20.146951083559543|               0.0|1655.8284359052777|    2|
# | 174.7326|         9.0| 84.851|1947.0|177.90647888183594|              9.0|113.62449645996094| 20.146951083559543|               0.0|1655.8284359052777|    2|
# |173.50485|         0.0| 93.707|1950.0|173.50485229492188|              0.0| 93.70700073242188|               null|              null|              null|    1|
# |220.15955|         7.0| 55.233|1953.0| 168.4762840270996|              6.0| 93.98375129699707|  2487.204302560907| 6.666666666666667| 1627.895951263078|    4|
# | 100.8322|         9.0| 75.064|1953.0| 168.4762840270996|              6.0| 93.98375129699707|  2487.204302560907| 6.666666666666667| 1627.895951263078|    4|
# |183.06567|         5.0| 96.731|1953.0| 168.4762840270996|              6.0| 93.98375129699707|  2487.204302560907| 6.666666666666667| 1627.895951263078|    4|
# +---------+------------+-------+------+------------------+-----------------+------------------+-------------------+------------------+------------------+-----+
# only showing top 20 rows

# %%
year = data3.rdd.map(lambda x: x["Year"]).collect()
dur = data3.rdd.map(lambda x: x["Mean Duration"]).collect()
key = data3.rdd.map(lambda x: x["Mean Key"]).collect()
temp = data3.rdd.map(lambda x: x["Mean Tempo"]).collect()
sddur = data3.rdd.map(lambda x: x["Mean Duration"]**0.5).collect()
sdkey = data3.rdd.map(lambda x: x["Mean Key"]**0.5).collect()
sdtemp = data3.rdd.map(lambda x: x["Mean Tempo"]**0.5).collect()
color = data3.rdd.map(lambda x: x["Count"]).collect()

# %%
plt.figure(figsize=(14, 5))

plt.subplot(131)
plt.scatter(year, dur, c=color, zorder=10)
plt.errorbar(year, dur, yerr=sddur, fmt=' ', ecolor='black', zorder=0)
plt.title("Song duration")
plt.xlabel("Year")
plt.ylabel("Time [s]")
plt.subplot(132)
plt.scatter(year, key, c=color, zorder=10)
plt.errorbar(year, key, yerr=sdkey, fmt=' ', ecolor='black', zorder=0)
plt.title("Key signature of song")
plt.xlabel("Year")
plt.ylabel("Chord")
plt.subplot(133)
plt.scatter(year, temp, c=color, zorder=10)
plt.errorbar(year, temp, yerr=sdtemp, fmt=' ', ecolor='black', zorder=0)
plt.title("Tempo of song")
plt.xlabel("Year")
plt.ylabel("BPM")
plt.suptitle('Trends in songs over the years')
plt.show()

# %%
spark_session.stop()
